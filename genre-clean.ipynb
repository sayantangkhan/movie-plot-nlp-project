# %%
import pandas as pd
import numpy as np
import regex as re
from collections import defaultdict
import heapq

# %% [markdown]
# ### Import and clean up Kaggle data. Movies which have duplicated title and release year are dropped. This set will include movies whose format has been messed up.

# %%
movie_plots = pd.read_csv("../Documents/Erdos Data Science Boot Camp/wiki_movie_plots_deduped.csv")
to_drop = movie_plots.loc[movie_plots.duplicated(subset=['Wiki Page'])]
movie_plots.drop(index=to_drop.index,inplace=True)
to_drop = movie_plots.loc[movie_plots.duplicated(subset=['Title','Release Year'],keep=False)]
movie_plots.drop(index=to_drop.index,inplace=True)

# %% [markdown]
# ### Necessary functions for cleaning up genre.

# %%
tags = {"romantic":"romance","comedy":"comedy","animation":"animation","horror":"horror","thriller":"thriller",
           "epic":"epic","musical":"musical","fantasy":"fantasy","science fiction":"science fiction",
        "sci-fi":"science fiction","action":"action","adventure":"adventure","drama":"drama","crime":"crime",
        "western":"western","historical":"historical fiction","animated":"animation"}
to_rename = {"crime fiction":"crime","clay animation":"animation","historical documentaries":"documentary",
             "animated cartoon":"animation"}
#political, space, slasher (all horror automatically?), costume drama -->historical fiction
def clean_genre(arr):
    ans = set()
    for s in arr:
        #remove ids and clean up formatting of each genre
        new_s = re.sub(' .ilm|\smovie','',re.sub('"/m/.*": ','',s))
        new_s = re.sub('"','',new_s)
        if new_s != '' and new_s[0] == ' ':
            new_s = new_s[1:]
            
        #split phrase into list of coarser genres
        genres = new_s.split('/')
        for genre in genres:
            genre = genre.lower()
            if genre == 'comedy-drama':
                ans.add('comedy')
                ans.add('drama')
            else:
                if genre in to_rename:
                    ans.add(to_rename[genre])
                else:
                    for substr in tags:
                        if substr in genre:
                            ans.add(tags[substr])
                    if genre != '':
                        ans.add(genre)
    return ans
def find_duplicates(x):
    return bool((x.Title in movie_plots.Title.values) and (x['Release Year'] in movie_plots.loc[movie_plots.Title == x.Title,"Release Year"].values))

# %% [markdown]
# ### Import and clean up cmu data. Movies with duplicate title and release year are dropped.

# %%
cmu_data = pd.read_csv("Data/cmu_movie_boxoffice.tsv",sep="\t",header=None)
cmu_data.drop(columns=[0,1,4,5,6,7],inplace=True)
cmu_data.rename(columns={2:"Title", 3:"Release Year",8:"Genre"},inplace=True)
cmu_data["Release Year"] = cmu_data["Release Year"].str.replace(r'-.*','',regex = True)
cmu_data = cmu_data.dropna()
cmu_data["Release Year"] = cmu_data["Release Year"].astype('int64')

cmu_data.Genre = cmu_data.Genre.apply(lambda s:s[1:len(s)-1])
cmu_data.Genre = cmu_data.Genre.apply(lambda x:x.split(','))
cmu_data.Genre = cmu_data.Genre.apply(lambda x: clean_genre(x))

cmu_dupl = cmu_data[cmu_data.duplicated(subset=['Title','Release Year'],keep=False)]
duplicates = cmu_dupl[cmu_dupl.apply(lambda row:find_duplicates(row),axis=1)]
cmu_data.drop(index=duplicates.index,inplace=True)

# %%
imdb_genres = defaultdict(int) #dictionary of counts with all IMDB GENRES
for movie in cmu_data.Genre.values:
    for genre in movie:
        imdb_genres[genre]+=1  

minHeap = []
n = 50
for key in imdb_genres:
    heapq.heappush(minHeap,[imdb_genres[key],key])
    if len(minHeap)>n:
        heapq.heappop(minHeap)
minHeap.sort() #returns top n most popular genres

# %%
imdb_genres
# Out:
# defaultdict(int,
#             {'adventure': 8432,
#              'western': 2232,
#              'supernatural': 635,
#              'action': 9557,
#              'thriller': 8904,
#              'space western': 13,
#              'science fiction': 2904,
#              'horror': 5003,
#              'drama': 33148,
#              'mystery': 3053,
#              'crime drama': 552,
#              'crime': 7773,
#              'biographical': 1099,
#              'psychological thriller': 1312,
#              'erotic thriller': 207,
#              'indie': 6769,
#              'silent': 5050,
#              'short': 7201,
#              'black-and-white': 8808,
#              'comedy': 20268,
#              'world cinema': 7144,
#              'fantasy': 2857,
#              'family': 4419,
#              'musical': 4106,
#              'japanese movies': 2083,
#              'romantic comedy': 2631,
#              'romantic drama': 3341,
#              'ensemble': 447,
#              'romance': 10599,
#              'film adaptation': 1526,
#              'period piece': 1739,
#              'war': 2533,
#              'epic': 332,
#              'costume drama': 479,
#              "children's": 1209,
#              "children's fantasy": 274,
#              'future noir': 33,
#              'coming of age': 896,
#              'crime thriller': 2106,
#              'black comedy': 1017,
#              'suspense': 752,
#              'bollywood': 1314,
#              'marriage drama': 182,
#              'martial arts': 889,
#              'chinese movies': 1370,
#              'wuxia': 119,
#              'parody': 991,
#              'mockumentary': 162,
#              'fan': 34,
#              'cult': 757,
#              'adventure comedy': 141,
#              'slapstick': 606,
#              'historical fiction': 870,
#              'biopic [feature]': 620,
#              'historical epic': 101,
#              'family drama': 1026,
#              'sports': 1138,
#              'political drama': 781,
#              'courtroom drama': 241,
#              'biography': 1362,
#              'documentary': 4999,
#              'culture & society': 710,
#              'christmas': 92,
#              'television': 968,
#              'malayalam cinema': 13,
#              'blaxploitation': 106,
#              'action comedy': 163,
#              'sci-fi horror': 141,
#              'erotica': 298,
#              'satire': 693,
#              'epic western': 17,
#              'gangster': 424,
#              'sexploitation': 124,
#              'softcore porn': 62,
#              'zombie': 270,
#              'b-movie': 492,
#              'action thrillers': 503,
#              'musical drama': 190,
#              'pornographic': 270,
#              'erotic drama': 149,
#              'slasher': 753,
#              'film noir': 612,
#              'social issues': 302,
#              'legal drama': 8,
#              'new hollywood': 88,
#              'history': 864,
#              'experimental': 246,
#              'avant-garde': 182,
#              'tragicomedy': 60,
#              'surrealism': 149,
#              'crime comedy': 304,
#              'animation': 3130,
#              'monster': 291,
#              'natural horrors': 172,
#              'creature': 382,
#              'lgbt': 1146,
#              'gender issues': 73,
#              'music': 1004,
#              'comedy of errors': 203,
#              'historical drama': 286,
#              'political thriller': 240,
#              'melodrama': 701,
#              'americana': 106,
#              'detective fiction': 331,
#              'detective': 395,
#              'concert': 277,
#              'horror comedy': 236,
#              'anime': 415,
#              'docudrama': 400,
#              'childhood drama': 142,
#              'teen': 916,
#              'gothic': 73,
#              'disaster': 281,
#              'art': 461,
#              'domestic comedy': 208,
#              'musical comedy': 233,
#              'family-oriented adventure': 243,
#              'escape': 55,
#              'prison': 131,
#              'dance': 113,
#              'superhero': 289,
#              'filipino movies': 327,
#              'filipino': 12,
#              'spy': 465,
#              'combats': 99,
#              'fantasy adventure': 217,
#              'political cinema': 414,
#              'c-movie': 1,
#              'comedy horror': 25,
#              'dystopia': 94,
#              'buddy': 369,
#              'tragedy': 99,
#              'time travel': 85,
#              'sword and sorcery': 50,
#              'political satire': 99,
#              'gross-out': 58,
#              'gross out': 58,
#              'plague': 5,
#              'doomsday': 121,
#              'propaganda': 199,
#              'screwball comedy': 295,
#              'comedy western': 72,
#              'gay interest': 283,
#              'gay themed': 353,
#              'gay': 285,
#              'film & television history': 79,
#              'film': 117,
#              'medical fiction': 78,
#              'costume adventure': 104,
#              'rockumentary': 192,
#              'feminist': 98,
#              'educational': 35,
#              'buddy cop': 13,
#              'film \\u00e0 clef': 33,
#              'costume horror': 62,
#              'pre-code': 177,
#              'juvenile delinquency': 54,
#              'christian': 156,
#              'natural disaster': 15,
#              'movie serial': 17,
#              'linguistics': 1,
#              'language & literature': 28,
#              'comedy of manners': 269,
#              'remake': 89,
#              'fantasy comedy': 220,
#              'media satire': 87,
#              'computer animation': 215,
#              'spaghetti western': 129,
#              'dogme 95': 28,
#              'backstage musical': 26,
#              'law & crime': 80,
#              'hybrid western': 37,
#              'stop motion': 164,
#              'roadshow theatrical release': 43,
#              'sex comedy': 318,
#              'tollywood': 46,
#              'women in prisons': 17,
#              'holiday': 108,
#              'heavenly comedy': 31,
#              'road': 337,
#              'giallo': 35,
#              'anthology': 14,
#              'existentialism': 36,
#              'social problem': 133,
#              'sci-fi adventure': 34,
#              'anthropology': 15,
#              'gay pornography': 68,
#              'auto racing': 77,
#              'slice of life story': 120,
#              'british new wave': 14,
#              'kitchen sink realism': 16,
#              'samurai cinema': 43,
#              'heist': 174,
#              'gulf war': 6,
#              'archaeology': 10,
#              'romantic fantasy': 72,
#              'religious': 71,
#              'biker': 25,
#              'animal picture': 181,
#              'absurdism': 91,
#              'swashbucklers': 125,
#              'hagiography': 27,
#              'hardcore pornography': 10,
#              'adult': 197,
#              'animated musical': 53,
#              'anti-war': 44,
#              'cavalry': 15,
#              'haunted house': 76,
#              'space opera': 5,
#              'czechoslovak new wave': 9,
#              'animals': 48,
#              'addiction drama': 60,
#              'punk rock': 68,
#              'chase movie': 108,
#              'tokusatsu': 3,
#              'pornography': 13,
#              'extreme sports': 30,
#              'apocalyptic and post-apocalyptic fiction': 35,
#              'whodunit': 79,
#              'environmental science': 32,
#              'airplanes and airports': 56,
#              'travel': 51,
#              'alien': 112,
#              'graphic & applied arts': 31,
#              'essay': 26,
#              'inspirational drama': 35,
#              'revisionist western': 68,
#              'pinku eiga': 29,
#              'stand-up comedy': 92,
#              'jungle': 78,
#              'fairy tale': 61,
#              'comedy thriller': 91,
#              'tamil cinema': 67,
#              'workplace comedy': 96,
#              'libraries and librarians': 5,
#              'caper story': 109,
#              'demonic child': 6,
#              'illnesses & disabilities': 53,
#              'expressionism': 3,
#              'glamorized spy': 50,
#              'early black cinema': 5,
#              'interpersonal relationships': 48,
#              'british empire': 25,
#              'sword and sorcerys': 43,
#              'b-western': 62,
#              'bengali cinema': 16,
#              'filmed play': 7,
#              'northern': 23,
#              'hip hops': 80,
#              'humour': 4,
#              'carny': 5,
#              'exploitation': 24,
#              'roadshow': 5,
#              'sword and sandal': 24,
#              'nature': 63,
#              'mumblecore': 9,
#              "children's entertainment": 13,
#              'splatter': 31,
#              'star vehicle': 2,
#              'business': 13,
#              'stoner': 51,
#              'mythological fantasy': 32,
#              'journalism': 9,
#              'camp': 3,
#              'boxing': 77,
#              'mondo': 13,
#              'latino': 6,
#              'alien invasion': 6,
#              'sponsored': 8,
#              'revenge': 2,
#              'foreign legion': 10,
#              'heaven-can-wait fantasies': 24,
#              'baseball': 10,
#              'conspiracy fiction': 2,
#              'master criminals': 31,
#              'jukebox musical': 8,
#              'indian western': 26,
#              'road-horror': 21,
#              'werewolf fiction': 4,
#              'feature': 14,
#              'neo-noir': 60,
#              'private military company': 2,
#              'computers': 8,
#              'finance & investing': 6,
#              'movies about gladiators': 6,
#              'horse racing': 14,
#              'nuclear warfare': 3,
#              'inventions & innovations': 13,
#              'instrumental music': 25,
#              'media studies': 35,
#              'archives and records': 8,
#              'psycho-biddy': 15,
#              'outlaw biker': 17,
#              'prison escape': 2,
#              'z': 3,
#              'news': 16,
#              'beach': 20,
#              'live action': 3,
#              'education': 7,
#              'health & fitness': 13,
#              'film-opera': 4,
#              'period horror': 2,
#              'comdedy': 1,
#              "children's issues": 5,
#              'science fiction western': 6,
#              'bloopers & candid camera': 5,
#              'psychological horror': 5,
#              'albino bias': 17,
#              'family & personal relationships': 16,
#              'steampunk': 35,
#              'fantasy drama': 19,
#              'sci-fi thriller': 5,
#              'courtroom comedy': 6,
#              'operetta': 5,
#              'parkour in popular culture': 6,
#              'cyberpunk': 4,
#              'coming-of-age': 5,
#              'cold war': 11,
#              'political documetary': 2,
#              'fictional': 8,
#              'world history': 20,
#              'reboot': 9,
#              'bruceploitation': 3,
#              'ealing comedies': 15,
#              'silhouette animation': 1,
#              'female buddy': 5,
#              'race': 4,
#              'breakdance': 1,
#              'acid western': 9,
#              'war effort': 1,
#              'school story': 5,
#              'supermarionation': 3,
#              'sci fi pictures originals': 5,
#              'outlaw': 5,
#              'kafkaesque': 6,
#              'vampires': 3,
#              'goat gland': 4,
#              'therimin music': 4,
#              'beach party': 2,
#              'singing cowboy': 5,
#              'point of view shot': 3,
#              'romantic thriller': 1,
#              'patriotic': 2,
#              'chick flick': 1,
#              'ninja': 2,
#              'buddy picture': 1,
#              'statutory rape': 1,
#              'new queer cinema': 1,
#              'neorealism': 1,
#              'the netherlands in world war ii': 2,
#              'revisionist fairy tale': 2,
#              'homoeroticism': 1})

# %% [markdown]
# ### Merge kaggle and cmu data.

# %%
data = movie_plots.merge(cmu_data, how = 'left', on = ['Title', 'Release Year'])
data.rename(columns={'Genre_y':'Genre'},inplace=True)
data.Genre.fillna(0,inplace=True)
def helper(x):
    if x==0:
        return set()
    else:
        return x
data.Genre = data.Genre.apply(lambda x:helper(x))

# %%
data.sample(20)
# Out:
#        Release Year                                              Title  \
# 25879          2006                                       Chup Chup Ke
# 31978          1950                                            Scandal
# 17208          2017                                 Jeepers Creepers 3
# 23903          1948                                      Ghar Ki Izzat
# 20475          1997                                          Metroland
# 26795          2003                                       Swathi Muthu
# 25504          1998                                              Zakhm
# 4883           1949                                           Hellfire
# 2139           1936                              Thirteen Hours by Air
# 30963          1962                                   Rakta Sambandham
# 19295          1959                                      Danger Within
# 9341           1977                                             Martin
# 19866          1970                                     The Go-Between
# 20688          2004                                          Wimbledon
# 31992          1954             Crucified Lovers !The Crucified Lovers
# 10452          1986                          The Clan of the Cave Bear
# 26919          2011                            Cool...Sakkath Hot Maga
# 8300           1968                           Night of the Living Dead
# 32767          2011  Doraemon: Nobita and the New Steel Troops: ~An...
# 22849          1987                                       Sister Cupid
#
#       Origin/Ethnicity                         Director  \
# 25879        Bollywood                     Priyadarshan
# 31978         Japanese                   Akira Kurosawa
# 17208         American                     Victor Salva
# 23903        Bollywood                      Ram Daryani
# 20475          British                   Philip Saville
# 26795          Kannada                 D. Rajendra Babu
# 25504        Bollywood                     Mahesh Bhatt
# 4883          American                 R.G. Springsteen
# 2139          American                  Mitchell Leisen
# 30963           Telugu                V. Madhusudan Rao
# 19295          British                      Don Chaffey
# 9341          American                 George A. Romero
# 19866          British                     Joseph Losey
# 20688          British                Richard Loncraine
# 31992         Japanese  Mizoguchi, KenjiKenji Mizoguchi
# 10452         American                  Michael Chapman
# 26919          Kannada                           Ganesh
# 8300          American                 George A. Romero
# 32767         Japanese                    Yuichi Shinbo
# 22849        Hong Kong                          Guy Lai
#
#                                                     Cast              Genre_x  \
# 25879  Kareena Kapoor, Shahid Kapoor, Neha Dhupia, Ra...      comedy, romance
# 31978                                     Toshirō Mifune                drama
# 17208  Victor Salva (director/screeplay); Jonathan Br...               horror
# 23903  Dilip Kumar, Mumtaz Shanti, Jeevan, Gope, Mano...  social family drama
# 20475                       Christian Bale, Emily Watson               comedy
# 26795                                      Sudeep, Meena              unknown
# 25504  Ajay Devgan, Sonali Bendre, Pooja Bhatt, Akkin...       nadeem-shravan
# 4883    Wild Bill Elliott, Marie Windsor, Forrest Tucker              western
# 2139            Fred MacMurray, Joan Bennett, ZaSu Pitts                drama
# 30963         N. T. Rama Rao, Savitri, Kanta Rao, Devika                drama
# 19295                          Richard Todd, Bernard Lee         world war ii
# 9341          John Amplas, Christine Forrest, Tom Savini               horror
# 19866                         Julie Christie, Alan Bates                drama
# 20688                        Kirsten Dunst, Paul Bettany               sports
# 31992        Kazuo Hasegawa, Kyōko Kagawa, Yoko Minamida              unknown
# 10452             Daryl Hannah, Pamela Reed, James Remar            adventure
# 26919                 Ganesh, Aamna Sharif, Sadhu Kokila              romance
# 8300                           Duane Jones, Judith O'Dea               horror
# 32767           Wasabi Mizuta, Megumi Ohara, Yumi Kakazu                anime
# 22849          Carol Cheng, Jackie Cheung, Maggie Cheung              unknown
#
#                                                Wiki Page  \
# 25879         https://en.wikipedia.org/wiki/Chup_Chup_Ke
# 31978  https://en.wikipedia.org/wiki/Scandal_(1950_film)
# 17208   https://en.wikipedia.org/wiki/Jeepers_Creepers_3
# 23903  https://en.wikipedia.org/wiki/Ghar_Ki_Izzat_(1...
# 20475  https://en.wikipedia.org/wiki/Metroland_(1997_...
# 26795         https://en.wikipedia.org/wiki/Swathi_Muthu
# 25504                https://en.wikipedia.org/wiki/Zakhm
# 4883   https://en.wikipedia.org/wiki/Hellfire_(1949_f...
# 2139   https://en.wikipedia.org/wiki/Thirteen_Hours_b...
# 30963  https://en.wikipedia.org/wiki/Rakta_Sambandham...
# 19295        https://en.wikipedia.org/wiki/Danger_Within
# 9341    https://en.wikipedia.org/wiki/Martin_(1978_film)
# 19866  https://en.wikipedia.org/wiki/The_Go-Between_(...
# 20688     https://en.wikipedia.org/wiki/Wimbledon_(film)
# 31992  https://en.wikipedia.org/wiki/The_Crucified_Lo...
# 10452  https://en.wikipedia.org/wiki/The_Clan_of_the_...
# 26919  https://en.wikipedia.org/wiki/Cool...Sakkath_H...
# 8300   https://en.wikipedia.org/wiki/Night_of_the_Liv...
# 32767  https://en.wikipedia.org/wiki/Doraemon:_Nobita...
# 22849         https://en.wikipedia.org/wiki/Sister_Cupid
#
#                                                     Plot  \
# 25879  Jeetu (Shahid Kapoor) is constantly getting hi...
# 31978  Ichiro Aoye (Toshirō Mifune), an artist, meets...
# 17208  The film opens with a shuriken flying through ...
# 23903  Chandra (Dilip Kumar, a young lawyer, lives in...
# 20475  In 1977, Chris (Christian Bale) and Marion (Em...
# 26795  Shivaiah (Sudeep), an autistic, lives in a vil...
# 25504  Music director Ajay (Ajay Devgn) argues with h...
# 4883   Drifting gambler Zeb Smith promises a dying pr...
# 2139   Airline pilot Jack Gordon (Fred MacMurray) on ...
# 30963  Raju (N. T. Rama Rao) & Radha (Savitri) are si...
# 19295  A cleverly planned escape attempt, which seeme...
# 9341   As the film opens, a young man, travelling on ...
# 19866  The story follows a young boy named Leo Colsto...
# 20688  Peter Colt, a British professional tennis play...
# 31992  Ishun (Shindo) is a wealthy but miserly scroll...
# 10452  A young Cro-Magnon woman named Ayla (Daryl Han...
# 26919  The film has supposedly a comedy and romance m...
# 8300   Barbra and Johnny Blair drive to rural Pennsyl...
# 32767  The movie's plot involves Nobita, who throws a...
# 22849  Kam Yu-yee (Carol Cheng) and Kam Kat-cheung (J...
#
#                                                    Genre
# 25879  {romantic comedy, world cinema, comedy of erro...
# 31978     {world cinema, drama, japanese movies, comedy}
# 17208                                                 {}
# 23903                                           {action}
# 20475  {indie, drama, marriage drama, romantic drama,...
# 26795                                                 {}
# 25504                   {bollywood, world cinema, drama}
# 4883                        {adventure, action, western}
# 2139                           {action, drama, disaster}
# 30963                                                 {}
# 19295                                                 {}
# 9341                                                  {}
# 19866  {romantic drama, romance, drama, film adaptation}
# 20688  {drama, romantic comedy, sports, romance, comedy}
# 31992                                                 {}
# 10452  {adventure, drama, action, fantasy, costume dr...
# 26919                                                 {}
# 8300   {indie, doomsday, cult, zombie, mystery, black...
# 32767                                  {japanese movies}
# 22849                                                 {}

# %% [markdown]
# ### Incorporate genres from Kaggle data

# %%
#movie_plots.Genre = movie_plots.Genre.apply(lambda x:re.split('/|,',x))
#go through and add genre_x genres to genre only if genre_x is an imdb genre 
for i in range(len(data)):
    wiki_genres = data.loc[i,"Genre_x"]
    genres = data.loc[i,"Genre"] 
    if wiki_genres != 'unknown':
        for val in imdb_genres: 
            if val in wiki_genres.lower():
                genres.add(val)

# %%
data.drop(columns=['Genre_x'],inplace=True)

# %%
data.to_csv('wiki_plots_with_genres')

# %% [markdown]
# ### Helper functions.

# %%
def search_by_pattern(arr,pattern): #looks through arr to find genres that contain the given pattern 
    ans = []
    for val in arr:
        if re.search(pattern,val):
            ans.append(val)
    return ans
#Example: search_by_pattern(imdb_genres,"anim")

# %%
search_by_pattern(imdb_genres,"family")
# Out:
# ['family',
#  'family drama',
#  'family-oriented adventure',
#  'family & personal relationships']

# %%
#make genre predictor/associated in the model?
