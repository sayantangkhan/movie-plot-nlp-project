# %%
import pandas as pd
import numpy as np
import regex as re
from collections import defaultdict
import heapq

# %% [markdown]
# ### Import and clean up Kaggle data. Movies which have duplicated title and release year are dropped. This set will include movies whose format has been messed up.

# %%
movie_plots = pd.read_csv("Data/wiki_movie_plots_deduped.csv.zip")
to_drop = movie_plots.loc[movie_plots.duplicated(subset=['Wiki Page'])]
movie_plots.drop(index=to_drop.index,inplace=True)
to_drop = movie_plots.loc[movie_plots.duplicated(subset=['Title','Release Year'],keep=False)]
movie_plots.drop(index=to_drop.index,inplace=True)

# %% [markdown]
# ### Necessary functions for cleaning up genre.

# %%
# all added genres will have no spaces (e.g., science-fiction, historical-fiction, coming-of-age,...)
tags = { # these are main genres to look for even if appear as a subword, 
         # e.g., "romantic comedy" gets "romance" & "comedy")
        "romantic":"romance", "comedy":"comedy", "drama":"drama", 
        "horror":"horror", "thriller":"thriller", 
        "fantasy":"fantasy", "science fiction":"science-fiction", "sci-fi":"science-fiction", 
        "epic":"epic", "action":"action", "adventure":"adventure", 
        "crime":"crime", "mystery":"mystery",
        "western":"western", "historical":"historical-fiction", 
        "animated":"animation", "animation":"animation", 
        "family":"family", "coming-of-age":"coming-of-age", "teen":"teen",
        "black-and-white":"black-and-white", "silent":"silent",
        "documentary":"documentary", "biographical":"biographical", "political":"political",
        "musical":"musical", "opera":"opera", "music":"music",
        "tragedy":"tragedy",
        # now these tags are the main genre for some common sub-genres
        "space":"science-fiction", 
        "costume drama":"historical-fiction", "period piece":"historical-fiction",
        "propaganda":"political",
        "slasher":"horror", "zombie":"horror", "psycho-biddy":"thriller",
        "splapstick":"comedy",
        "operetta":"opera", "rock":"music", "hip hops":"music", "concert":"music",
        "whodunit":"mystery", "detective":"mystery", 
        "anime":"animation", "nature":"documentary",
        "superhero":"action", "spy":"action", "swashbucklers":"adventure",
        "avant-garde":"experimental", "surrealism":"experimental", "art":"experimental"}
# to standardize spellings/phrasings
to_rename = {"crime fiction":"crime", "clay animation":"animation", "historical documentaries":"documentary",
             "animated cartoon":"animation", "coming of age":"coming-of-age",
             "biopic":"biographical", "biography":"biographical"}
def clean_genre(arr):
    """ Returns a set of genres corresponding to the original (sub)genres in arr, but with more standardized
    names & with larger genre categories added if necessary.
    
    PARAMETERS:
    arr: a list of genres, as originally formatted (and split into a list) by the CMU dataset
    """
    ans = set()
    for s in arr:
        #remove ids and clean up formatting of each genre
        new_s = re.sub(' .ilm|\smovie','',re.sub('"/m/.*": ','',s))
        new_s = re.sub('"','',new_s)
        if new_s != '' and new_s[0] == ' ':
            new_s = new_s[1:]
            
        #split phrase into list of coarser genres
        genres = new_s.split('/')
        for genre in genres:
            genre = genre.lower()
            if genre == 'comedy-drama':
                ans.add('comedy')
                ans.add('drama')
            elif genre == "rockumentary":
                ans.add("music")
                ans.add("rock")
                ans.add("documentary")
            elif genre == "tragicomedy":
                ans.add("tragedy")
                ans.add("comedy")
            else:
                if genre in to_rename:
                    ans.add(to_rename[genre])
                else:
                    for substr in tags:
                        if substr in genre:
                            ans.add(tags[substr])
                    if genre != '':
                        ans.add(genre)
    return ans


def find_duplicates(x):
    """ Returns True iff the movie represented by x is a duplicate of some movie in movie_plots
    
    PARAMETERS:
    x: a series which represents a "row" in some kind of movie DataFrame
    """
    is_title_dupl = (x.Title in movie_plots.Title.values)
    is_year_dupl = (x['Release Year'] in movie_plots.loc[movie_plots.Title == x.Title,"Release Year"].values)
    return bool( is_title_dupl and is_year_dupl)

# %% [markdown]
# ### Import and clean up cmu data. Movies with duplicate title and release year are dropped.

# %%
cmu_data = pd.read_csv("Data/cmu_movie_boxoffice.tsv",sep="\t",header=None)
cmu_data.drop(columns=[0,1,4,5,6,7],inplace=True)
cmu_data.rename(columns={2:"Title", 3:"Release Year",8:"Genre"},inplace=True)
cmu_data["Release Year"] = cmu_data["Release Year"].str.replace(r'-.*','',regex = True)
cmu_data = cmu_data.dropna()
cmu_data["Release Year"] = cmu_data["Release Year"].astype('int64')

cmu_data.Genre = cmu_data.Genre.apply(lambda s:s[1:len(s)-1])
cmu_data.Genre = cmu_data.Genre.apply(lambda x:x.split(','))
cmu_data.Genre = cmu_data.Genre.apply(lambda x: clean_genre(x))

cmu_dupl = cmu_data[cmu_data.duplicated(subset=['Title','Release Year'],keep=False)]
duplicates = cmu_dupl[cmu_dupl.apply(find_duplicates, axis=1)] # functions are 1st class objects, lambda optional
cmu_data.drop(index=duplicates.index,inplace=True)

# %%
imdb_genres = defaultdict(int) #dictionary of counts with all IMDB GENRES
for movie in cmu_data.Genre.values:
    for genre in movie:
        imdb_genres[genre]+=1  

minHeap = []
n = 50
for key in imdb_genres:
    heapq.heappush(minHeap,[imdb_genres[key],key])
    if len(minHeap)>n:
        heapq.heappop(minHeap)
minHeap.sort() #returns top n most popular genres

pop_gens = [it[1] for it in minHeap]
minHeap
def has_overlap(row):
    overlap = False
    for genre in pop_gens:
        overlap = overlap or (genre in row["Genre"])
    return(overlap)
filt = [not has_overlap(cmu_data.iloc[i]) for i in range(len(cmu_data))]
cmu_data.loc[ filt ]
# Out:
#                            Title  Release Year                           Genre
# 18      Die Fahne von Kriwoj Rog          1967                              {}
# 32                Emilia Galotti          1958                              {}
# 42      Vinayaka Geleyara Balaga          2011                              {}
# 50     Behind The Player: John 5          2008                              {}
# 93                        Vixen!          1968  {softcore porn, sexploitation}
# ...                          ...           ...                             ...
# 81581           Ne daj se, Floki          2000                              {}
# 81681              Aachariyangal          2012                              {}
# 81693              Fiete im Netz          1958                              {}
# 81706             Fierro a fondo          1952                              {}
# 81712             Morir por nada          1974                              {}
#
# [2161 rows x 3 columns]

# %%
small_genres = defaultdict(int) #dictionary of counts with all IMDB GENRES
for movie in cmu_data.loc[filt].Genre.values:
    for genre in movie:
        small_genres[genre]+=1  
small_genres
# Out:
# defaultdict(int,
#             {'softcore porn': 6,
#              'sexploitation': 13,
#              'film noir': 28,
#              'pornographic': 131,
#              'filipino movies': 52,
#              'dogme 95': 3,
#              'gay pornography': 52,
#              'satire': 6,
#              'dance': 5,
#              'blaxploitation': 4,
#              'educational': 4,
#              'religious': 9,
#              'social issues': 3,
#              'culture & society': 12,
#              'revenge': 1,
#              'pornography': 4,
#              'adult': 54,
#              'hardcore pornography': 6,
#              'inventions & innovations': 1,
#              'suspense': 4,
#              'women in prisons': 1,
#              'erotica': 24,
#              'christmas': 5,
#              'remake': 1,
#              'pre-code': 6,
#              'auto racing': 2,
#              'stop motion': 4,
#              'mockumentary': 8,
#              'mondo': 1,
#              'christian': 3,
#              'reboot': 1,
#              'tollywood': 3,
#              'fan': 2,
#              'opera': 1,
#              'operetta': 1,
#              'epic': 7,
#              'sponsored': 4,
#              'bengali cinema': 1,
#              'gangster': 5,
#              'feature': 2,
#              'heist': 1,
#              'sword and sorcery': 1,
#              'wuxia': 4,
#              'kitchen sink realism': 1,
#              'road': 2,
#              'time travel': 2,
#              'tamil cinema': 2,
#              'buddy': 1,
#              'pinku eiga': 2,
#              'social problem': 2,
#              'anthology': 2,
#              'exploitation': 2,
#              'sword and sandal': 1,
#              'gay interest': 2,
#              'gay': 2,
#              'gay themed': 2,
#              'disaster': 2,
#              'fairy tale': 2,
#              'environmental science': 1,
#              'fictional': 1,
#              'computers': 1,
#              'business': 1,
#              'northern': 1,
#              'outlaw biker': 1,
#              'czechoslovak new wave': 1})

# %%
minHeap
# Out:
# [[757, 'cult'],
#  [781, 'political drama'],
#  [864, 'history'],
#  [889, 'martial arts'],
#  [901, 'coming-of-age'],
#  [916, 'teen'],
#  [968, 'television'],
#  [991, 'parody'],
#  [1017, 'black comedy'],
#  [1026, 'family drama'],
#  [1138, 'sports'],
#  [1146, 'lgbt'],
#  [1209, "children's"],
#  [1312, 'psychological thriller'],
#  [1314, 'bollywood'],
#  [1370, 'chinese movies'],
#  [1526, 'film adaptation'],
#  [1536, 'political'],
#  [1694, 'experimental'],
#  [1739, 'period piece'],
#  [2083, 'japanese movies'],
#  [2106, 'crime thriller'],
#  [2161, 'biographical'],
#  [2232, 'western'],
#  [2533, 'war'],
#  [2631, 'romantic comedy'],
#  [2742, 'historical-fiction'],
#  [2857, 'fantasy'],
#  [2884, 'science fiction'],
#  [2905, 'science-fiction'],
#  [3153, 'mystery'],
#  [3246, 'animation'],
#  [3341, 'romantic drama'],
#  [4106, 'musical'],
#  [5038, 'documentary'],
#  [5048, 'horror'],
#  [5050, 'silent'],
#  [5137, 'family'],
#  [5201, 'music'],
#  [6769, 'indie'],
#  [7144, 'world cinema'],
#  [7201, 'short'],
#  [7773, 'crime'],
#  [8445, 'adventure'],
#  [8808, 'black-and-white'],
#  [8907, 'thriller'],
#  [9763, 'action'],
#  [10599, 'romance'],
#  [20268, 'comedy'],
#  [33148, 'drama']]

# %%
cmu_data.iloc[filt].sample(20)
# Out:
#                             Title  Release Year  \
# 48578                 The Beloved          1966
# 53633                Poojapushpam          1969
# 13796  Charice: One for the Heart          2012
# 49410            Suburban Secrets          2004
# 76094                  Anveshanam          1972
# 27215              Savaale Samali          1971
# 78285                   It's Time          2006
# 65282     Shadow Over The Islands          1952
# 13978             Slave of Dreams          1995
# 24873           The Life of Nephi          1915
# 68221              Pattuthoovaala          1965
# 12123                     Jackpot          1993
# 57977                    Paattali          1999
# 13847              Le insaziabili          1958
# 48933             Klanta Aparahna          1985
# 73148                Poochakkanni          1966
# 30939                          MN          1954
# 59645             Dibratrir Kabya          1970
# 42988                       Ranga          1982
# 35634                     Vardaan          1975
#
#                                       Genre
# 48578                                    {}
# 53633                                    {}
# 13796                                    {}
# 49410  {adult, pornographic, softcore porn}
# 76094                                    {}
# 27215                                    {}
# 78285                                    {}
# 65282                                    {}
# 13978                           {christian}
# 24873                                    {}
# 68221                                    {}
# 12123                                    {}
# 57977                                    {}
# 13847                                    {}
# 48933                                    {}
# 73148                                    {}
# 30939                     {filipino movies}
# 59645                                    {}
# 42988                                    {}
# 35634                                    {}

# %%
imdb_genres
# Out:
# defaultdict(int,
#             {'supernatural': 635,
#              'adventure': 8445,
#              'space western': 13,
#              'science fiction': 2884,
#              'science-fiction': 2905,
#              'western': 2232,
#              'action': 9763,
#              'horror': 5048,
#              'thriller': 8907,
#              'mystery': 3153,
#              'crime drama': 552,
#              'drama': 33148,
#              'crime': 7773,
#              'biographical': 2161,
#              'psychological thriller': 1312,
#              'erotic thriller': 207,
#              'comedy': 20268,
#              'short': 7201,
#              'indie': 6769,
#              'black-and-white': 8808,
#              'silent': 5050,
#              'family': 5137,
#              'fantasy': 2857,
#              'world cinema': 7144,
#              'musical': 4106,
#              'music': 5201,
#              'japanese movies': 2083,
#              'romantic comedy': 2631,
#              'romantic drama': 3341,
#              'romance': 10599,
#              'ensemble': 447,
#              'historical-fiction': 2742,
#              'epic': 332,
#              'period piece': 1739,
#              'war': 2533,
#              'costume drama': 479,
#              'film adaptation': 1526,
#              "children's": 1209,
#              "children's fantasy": 274,
#              'future noir': 33,
#              'coming-of-age': 901,
#              'crime thriller': 2106,
#              'suspense': 752,
#              'black comedy': 1017,
#              'bollywood': 1314,
#              'marriage drama': 182,
#              'chinese movies': 1370,
#              'martial arts': 889,
#              'experimental': 1694,
#              'wuxia': 119,
#              'mockumentary': 162,
#              'parody': 991,
#              'fan': 34,
#              'slapstick': 606,
#              'cult': 757,
#              'adventure comedy': 141,
#              'biopic [feature]': 620,
#              'historical epic': 101,
#              'sports': 1138,
#              'family drama': 1026,
#              'political': 1536,
#              'political drama': 781,
#              'historical fiction': 556,
#              'courtroom drama': 241,
#              'documentary': 5038,
#              'culture & society': 710,
#              'television': 968,
#              'christmas': 92,
#              'malayalam cinema': 13,
#              'action comedy': 163,
#              'blaxploitation': 106,
#              'sci-fi horror': 141,
#              'satire': 693,
#              'erotica': 298,
#              'epic western': 17,
#              'gangster': 424,
#              'softcore porn': 62,
#              'sexploitation': 124,
#              'b-movie': 492,
#              'zombie': 270,
#              'action thrillers': 503,
#              'musical drama': 190,
#              'pornographic': 270,
#              'erotic drama': 149,
#              'slasher': 753,
#              'film noir': 612,
#              'social issues': 302,
#              'legal drama': 8,
#              'new hollywood': 88,
#              'history': 864,
#              'surrealism': 149,
#              'avant-garde': 182,
#              'tragedy': 157,
#              'crime comedy': 304,
#              'animation': 3246,
#              'monster': 291,
#              'creature': 382,
#              'natural horrors': 172,
#              'gender issues': 73,
#              'lgbt': 1146,
#              'comedy of errors': 203,
#              'historical drama': 286,
#              'political thriller': 240,
#              'melodrama': 701,
#              'americana': 106,
#              'detective': 395,
#              'detective fiction': 331,
#              'concert': 277,
#              'horror comedy': 236,
#              'anime': 415,
#              'childhood drama': 142,
#              'docudrama': 400,
#              'teen': 916,
#              'gothic': 73,
#              'disaster': 281,
#              'art': 461,
#              'domestic comedy': 208,
#              'musical comedy': 233,
#              'family-oriented adventure': 243,
#              'escape': 55,
#              'prison': 131,
#              'dance': 113,
#              'superhero': 289,
#              'filipino movies': 327,
#              'filipino': 12,
#              'spy': 465,
#              'combats': 99,
#              'fantasy adventure': 217,
#              'political cinema': 414,
#              'c-movie': 1,
#              'comedy horror': 25,
#              'dystopia': 94,
#              'buddy': 369,
#              'time travel': 85,
#              'sword and sorcery': 50,
#              'political satire': 99,
#              'gross out': 58,
#              'gross-out': 58,
#              'doomsday': 121,
#              'plague': 5,
#              'propaganda': 199,
#              'screwball comedy': 295,
#              'comedy western': 72,
#              'gay interest': 283,
#              'gay': 285,
#              'gay themed': 353,
#              'film & television history': 79,
#              'film': 117,
#              'medical fiction': 78,
#              'costume adventure': 104,
#              'rock': 192,
#              'feminist': 98,
#              'educational': 35,
#              'buddy cop': 13,
#              'film \\u00e0 clef': 33,
#              'costume horror': 62,
#              'pre-code': 177,
#              'juvenile delinquency': 54,
#              'christian': 156,
#              'natural disaster': 15,
#              'movie serial': 17,
#              'language & literature': 28,
#              'linguistics': 1,
#              'comedy of manners': 269,
#              'remake': 89,
#              'fantasy comedy': 220,
#              'media satire': 87,
#              'computer animation': 215,
#              'spaghetti western': 129,
#              'dogme 95': 28,
#              'backstage musical': 26,
#              'law & crime': 80,
#              'hybrid western': 37,
#              'stop motion': 164,
#              'roadshow theatrical release': 43,
#              'sex comedy': 318,
#              'tollywood': 46,
#              'women in prisons': 17,
#              'holiday': 108,
#              'heavenly comedy': 31,
#              'road': 337,
#              'giallo': 35,
#              'anthology': 14,
#              'existentialism': 36,
#              'social problem': 133,
#              'sci-fi adventure': 34,
#              'anthropology': 15,
#              'gay pornography': 68,
#              'auto racing': 77,
#              'slice of life story': 120,
#              'british new wave': 14,
#              'kitchen sink realism': 16,
#              'samurai cinema': 43,
#              'heist': 174,
#              'gulf war': 6,
#              'archaeology': 10,
#              'romantic fantasy': 72,
#              'religious': 71,
#              'biker': 25,
#              'animal picture': 181,
#              'absurdism': 91,
#              'swashbucklers': 125,
#              'hagiography': 27,
#              'adult': 197,
#              'hardcore pornography': 10,
#              'animated musical': 53,
#              'anti-war': 44,
#              'cavalry': 15,
#              'haunted house': 76,
#              'opera': 14,
#              'space opera': 5,
#              'czechoslovak new wave': 9,
#              'animals': 48,
#              'addiction drama': 60,
#              'punk rock': 68,
#              'chase movie': 108,
#              'tokusatsu': 3,
#              'pornography': 13,
#              'extreme sports': 30,
#              'apocalyptic and post-apocalyptic fiction': 35,
#              'whodunit': 79,
#              'environmental science': 32,
#              'airplanes and airports': 56,
#              'travel': 51,
#              'alien': 112,
#              'graphic & applied arts': 31,
#              'essay': 26,
#              'inspirational drama': 35,
#              'revisionist western': 68,
#              'pinku eiga': 29,
#              'stand-up comedy': 92,
#              'jungle': 78,
#              'fairy tale': 61,
#              'comedy thriller': 91,
#              'tamil cinema': 67,
#              'libraries and librarians': 5,
#              'workplace comedy': 96,
#              'caper story': 109,
#              'demonic child': 6,
#              'illnesses & disabilities': 53,
#              'expressionism': 3,
#              'glamorized spy': 50,
#              'early black cinema': 5,
#              'interpersonal relationships': 48,
#              'british empire': 25,
#              'sword and sorcerys': 43,
#              'b-western': 62,
#              'bengali cinema': 16,
#              'filmed play': 7,
#              'northern': 23,
#              'hip hops': 80,
#              'humour': 4,
#              'exploitation': 24,
#              'roadshow': 5,
#              'carny': 5,
#              'sword and sandal': 24,
#              'nature': 63,
#              'mumblecore': 9,
#              "children's entertainment": 13,
#              'splatter': 31,
#              'star vehicle': 2,
#              'business': 13,
#              'stoner': 51,
#              'mythological fantasy': 32,
#              'journalism': 9,
#              'camp': 3,
#              'boxing': 77,
#              'mondo': 13,
#              'latino': 6,
#              'alien invasion': 6,
#              'sponsored': 8,
#              'revenge': 2,
#              'foreign legion': 10,
#              'heaven-can-wait fantasies': 24,
#              'baseball': 10,
#              'conspiracy fiction': 2,
#              'master criminals': 31,
#              'jukebox musical': 8,
#              'indian western': 26,
#              'road-horror': 21,
#              'werewolf fiction': 4,
#              'feature': 14,
#              'neo-noir': 60,
#              'private military company': 2,
#              'computers': 8,
#              'finance & investing': 6,
#              'movies about gladiators': 6,
#              'horse racing': 14,
#              'nuclear warfare': 3,
#              'inventions & innovations': 13,
#              'instrumental music': 25,
#              'media studies': 35,
#              'archives and records': 8,
#              'psycho-biddy': 15,
#              'outlaw biker': 17,
#              'prison escape': 2,
#              'z': 3,
#              'news': 16,
#              'beach': 20,
#              'live action': 3,
#              'education': 7,
#              'health & fitness': 13,
#              'film-opera': 4,
#              'period horror': 2,
#              'comdedy': 1,
#              "children's issues": 5,
#              'science fiction western': 6,
#              'bloopers & candid camera': 5,
#              'psychological horror': 5,
#              'albino bias': 17,
#              'family & personal relationships': 16,
#              'steampunk': 35,
#              'fantasy drama': 19,
#              'sci-fi thriller': 5,
#              'courtroom comedy': 6,
#              'operetta': 5,
#              'parkour in popular culture': 6,
#              'cyberpunk': 4,
#              'cold war': 11,
#              'political documetary': 2,
#              'fictional': 8,
#              'world history': 20,
#              'reboot': 9,
#              'bruceploitation': 3,
#              'ealing comedies': 15,
#              'silhouette animation': 1,
#              'female buddy': 5,
#              'race': 4,
#              'breakdance': 1,
#              'acid western': 9,
#              'war effort': 1,
#              'school story': 5,
#              'supermarionation': 3,
#              'sci fi pictures originals': 5,
#              'outlaw': 5,
#              'kafkaesque': 6,
#              'vampires': 3,
#              'goat gland': 4,
#              'therimin music': 4,
#              'beach party': 2,
#              'singing cowboy': 5,
#              'point of view shot': 3,
#              'romantic thriller': 1,
#              'patriotic': 2,
#              'chick flick': 1,
#              'ninja': 2,
#              'buddy picture': 1,
#              'statutory rape': 1,
#              'new queer cinema': 1,
#              'neorealism': 1,
#              'the netherlands in world war ii': 2,
#              'revisionist fairy tale': 2,
#              'homoeroticism': 1})

# %% [markdown]
# ### Merge kaggle and cmu data.

# %%
data = movie_plots.merge(cmu_data, how = 'left', on = ['Title', 'Release Year'])
data.rename(columns={'Genre_y':'Genre'},inplace=True)
data.Genre.fillna(0,inplace=True)
def helper(x):
    if x==0:
        return set()
    else:
        return x
data.Genre = data.Genre.apply(helper)

# %%
data.sample(20)
# Out:
#        Release Year                                      Title  \
# 10070          1983                       Revenge of the Ninja
# 16948          2016                                       Race
# 21612          1995                                  Skin Deep
# 22441          2016                             Mr. High Heels
# 19744          1967                           The Viking Queen
# 7728           1963                           Pent-House Mouse
# 18815          1950                         Tony Draws a Horse
# 20005          1973                               The Hireling
# 12489          1995                The Stars Fell on Henrietta
# 11066          1989                 Back to the Future Part II
# 15194          2007                              Mister Lonely
# 17738          2011                             A Few Best Men
# 25956          2007                          Gauri: The Unborn
# 25545          1999                                  Sarfarosh
# 12948          1997                              The Informant
# 27020          2016                            Jai Maruthi 800
# 22560          1954  Sira` Fi al-Wadi (Struggle in the Valley)
# 17755          2012                                 Last Dance
# 14455          2004                            Shall We Dance?
# 22547          1949           Al-Yateematain (The Two Orphans)
#
#       Origin/Ethnicity              Director  \
# 10070         American       Sam Firstenberg
# 16948         American       Stephen Hopkins
# 21612         Canadian          Midi Onodera
# 22441          Chinese                 Lu Ke
# 19744          British           Don Chaffey
# 7728          American           Chuck Jones
# 18815          British  John Paddy Carstairs
# 20005          British          Alan Bridges
# 12489         American           James Keach
# 11066         American       Robert Zemeckis
# 15194         American        Harmony Korine
# 17738       Australian       Stephan Elliott
# 25956        Bollywood            Akku Akbar
# 25545        Bollywood  John Matthew Matthan
# 12948         American           Jim McBride
# 27020          Kannada             A. Harsha
# 22560         Egyptian       Youssef Chahine
# 17755       Australian        David Pulbrook
# 14455         American         Peter Chelsom
# 22547         Egyptian        Hassan Al Imam
#
#                                                     Cast  \
# 10070                         Sho Kosugi, Arthur Roberts
# 16948    Stephan James\r\nJason Sudeikis\r\nJeremy Irons
# 21612       Melanie Nicholls-King, Keram Malicki-Sánchez
# 22441  Du Jiang, Fiona Sit, Yu Xintian, Chen Xuedong,...
# 19744                                 Don Murray, Carita
# 7728                                                 NaN
# 18815                        Cecil Parker, Anne Crawford
# 20005                           Robert Shaw, Sarah Miles
# 12489          Robert Duvall, Aidan Quinn, Brian Dennehy
# 11066    Michael J. Fox, Christopher Lloyd, Lea Thompson
# 15194                        Diego Luna, Samantha Morton
# 17738                         Laura Brent, Xavier Samuel
# 25956                  Rituparna Sengupta, Atul Kulkarni
# 25545        Aamir Khan, Sonali Bendre, Naseeruddin Shah
# 12948                         Cary Elwes, Timothy Dalton
# 27020  Sharan, Shruti Hariharan, Shubha Poonja, Sadhu...
# 22560            Faten Hamama, Omar Sharif, Farid Shawki
# 17755           Firass Dirani, Julia Blake, Alan Hopgood
# 14455       Richard Gere, Jennifer Lopez, Susan Sarandon
# 22547                                       Faten Hamama
#
#                                               Genre_x  \
# 10070                                          action
# 16948                                    sports drama
# 21612  drama co-produced with the national film board
# 22441                                comedy / romance
# 19744                                      historical
# 7728                                         animated
# 18815                                          comedy
# 20005                                           drama
# 12489                                           drama
# 11066                         science fiction, comedy
# 15194                                    comedy-drama
# 17738                                          comedy
# 25956                                          horror
# 25545                                action, thriller
# 12948                                           drama
# 27020                                          comedy
# 22560                                 drama / romance
# 17755                                        thriller
# 14455                                         romance
# 22547                                   drama / crime
#
#                                                Wiki Page  \
# 10070  https://en.wikipedia.org/wiki/Revenge_of_the_N...
# 16948     https://en.wikipedia.org/wiki/Race_(2016_film)
# 21612  https://en.wikipedia.org/wiki/Skin_Deep_(1995_...
# 22441       https://en.wikipedia.org/wiki/Mr._High_Heels
# 19744     https://en.wikipedia.org/wiki/The_Viking_Queen
# 7728      https://en.wikipedia.org/wiki/Pent-House_Mouse
# 18815   https://en.wikipedia.org/wiki/Tony_Draws_a_Horse
# 20005         https://en.wikipedia.org/wiki/The_Hireling
# 12489  https://en.wikipedia.org/wiki/The_Stars_Fell_o...
# 11066  https://en.wikipedia.org/wiki/Back_to_the_Futu...
# 15194        https://en.wikipedia.org/wiki/Mister_Lonely
# 17738       https://en.wikipedia.org/wiki/A_Few_Best_Men
# 25956    https://en.wikipedia.org/wiki/Gauri:_The_Unborn
# 25545            https://en.wikipedia.org/wiki/Sarfarosh
# 12948  https://en.wikipedia.org/wiki/The_Informant_(f...
# 27020      https://en.wikipedia.org/wiki/Jai_Maruthi_800
# 22560   https://en.wikipedia.org/wiki/Sira%60_Fi_al-Wadi
# 17755  https://en.wikipedia.org/wiki/Last_Dance_(2012...
# 14455  https://en.wikipedia.org/wiki/Shall_We_Dance%3...
# 22547       https://en.wikipedia.org/wiki/Al-Yateematain
#
#                                                     Plot  \
# 10070  In Japan, the home of Cho Osaki is attacked by...
# 16948  Jesse Owens, a promising black American runner...
# 21612  Skin Deep tells the story of an award-winning ...
# 22441  Hang Yuan, a man who's been in love with a fri...
# 19744  According to her father's wishes, Queen Salina...
# 7728   Tom is relaxing in a penthouse, while Jerry is...
# 18815  When their eight-year-old son Tony (Anthony La...
# 20005  Set in and around Bath, Somerset, immediately ...
# 12489  The setting is early America during the oil bo...
# 11066  On October 26, 1985, Dr. Emmett Brown arrives ...
# 15194  A young man living in Paris scratches out a li...
# 17738  When David Locking (Samuel) proposes to his gi...
# 25956  When Roshni and Sudeep take their nine-year-ol...
# 25545  Arms trafficking is taking place in India. An ...
# 12948  The film tells the story of Sean Pius McAnally...
# 27020  Jeeva ([[Sharan]]) must correct the mistakes u...
# 22560  Omar Sharif plays Ahmed, an engineer whose fat...
# 17755  A Muslim man (Firass Dirani) kidnaps an elderl...
# 14455  John Clark is a lawyer with a charming wife, B...
# 22547  Hamama portrays the role of Neimat, a young gi...
#
#                                                    Genre
# 10070  {adventure, drama, action thrillers, indie, ex...
# 16948                                                 {}
# 21612                                      {drama, lgbt}
# 22441                                                 {}
# 19744                                                 {}
# 7728                                                  {}
# 18815                                    {comedy, drama}
# 20005                   {romance, drama, romantic drama}
# 12489                                 {americana, drama}
# 11066  {time travel, family, comedy, adventure, humou...
# 15194                                                 {}
# 17738                                                 {}
# 25956  {bollywood, world cinema, musical, drama, musi...
# 25545          {musical, world cinema, music, bollywood}
# 12948                                            {drama}
# 27020                                                 {}
# 22560                                                 {}
# 17755                                                 {}
# 14455  {comedy, romantic comedy, dance, drama, romanc...
# 22547                                                 {}

# %% [markdown]
# ### Incorporate genres from Kaggle data

# %%
#movie_plots.Genre = movie_plots.Genre.apply(lambda x:re.split('/|,',x))
#go through and add genre_x genres to genre only if genre_x is an imdb genre 
for i in range(len(data)):
    wiki_genres = data.loc[i,"Genre_x"]
    genres = data.loc[i,"Genre"] 
    if wiki_genres != 'unknown':
        for val in imdb_genres: 
            if val in wiki_genres.lower():
                genres.add(val)

# %%
data.drop(columns=['Genre_x'],inplace=True)

# %%
data.to_csv('Data/wiki_plots_with_genres.csv.zip', compression="zip")

# %% [markdown]
# ### Helper functions.

# %%
def search_by_pattern(arr,pattern): #looks through arr to find genres that contain the given pattern
    """ Given a list arr, return all entries which contain pattern as a substring.
    
    PARAMETERS:
    arr: a list (or other iterable container) of strings
    pattern: a string
    """
    ans = []
    for val in arr:
        if re.search(pattern,val):
            ans.append(val)
    return ans
#Example: search_by_pattern(imdb_genres,"anim")

# %%
search_by_pattern(imdb_genres,"short")
# Out:
# ['short']

# %%
type(cmu_dupl.iloc[1].loc["Genre"])
# Out:
# set

# %%
find_duplicates(cmu_dupl.iloc[1])
# Out:
# False

# %%
type(cmu_dupl.iloc[1])
# Out:
# pandas.core.series.Series

# %%
#make genre predictor/associated in the model?
