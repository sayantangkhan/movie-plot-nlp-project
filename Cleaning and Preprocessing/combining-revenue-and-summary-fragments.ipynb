# %%
import pandas as pd

# %%
with_to_embed = pd.read_csv("../Data/wiki_movies_no_cites.zip")
with_revenue = pd.read_csv("../Data/wiki_movie_plots_deduped_c2.csv")

# %%
with_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    34886 non-null  int64
#  1   Release Year  34886 non-null  int64
#  2   Title         34886 non-null  object
#  3   Origin        34886 non-null  object
#  4   Director      33762 non-null  object
#  5   Cast          33460 non-null  object
#  6   Genre         34886 non-null  object
#  7   Wiki Page     34886 non-null  object
#  8   Plot          34886 non-null  object
#  9   Revenue       5994 non-null   float64
#  10  to_embed      34886 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 2.9+ MB

# %%
with_to_embed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        34886 non-null  int64
#  1   Release Year      34886 non-null  int64
#  2   Title             34886 non-null  object
#  3   Origin/Ethnicity  34886 non-null  object
#  4   Director          34886 non-null  object
#  5   Cast              33464 non-null  object
#  6   Genre             34884 non-null  object
#  7   Wiki Page         34886 non-null  object
#  8   Plot              34886 non-null  object
#  9   to_embed          34886 non-null  object
#  10  Revenue           5994 non-null   float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 2.9+ MB

# %%
with_revenue['to_embed'] = with_to_embed['to_embed']

# %%
with_revenue.to_csv("../Data/wiki_with_revenue.csv", index=False, compression="zip")

# %%
combined = pd.read_csv("../Data/wiki_with_revenue.csv", compression="zip")

# %%
combined
# Out:
#        Unnamed: 0  Release Year                             Title    Origin  \
# 0               0          1901            Kansas Saloon Smashers  American
# 1               1          1901     Love by the Light of the Moon  American
# 2               2          1901           The Martyred Presidents  American
# 3               3          1901  Terrible Teddy, the Grizzly King  American
# 4               4          1902            Jack and the Beanstalk  American
# ...           ...           ...                               ...       ...
# 34881       34881          2014                 The Water Diviner   Turkish
# 34882       34882          2017                Çalgı Çengi İkimiz   Turkish
# 34883       34883          2017                      Olanlar Oldu   Turkish
# 34884       34884          2017                  Non-Transferable   Turkish
# 34885       34885          2017                İstanbul Kırmızısı   Turkish
#
#                                  Director  \
# ...
